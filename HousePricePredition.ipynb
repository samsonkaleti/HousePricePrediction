# %% [markdown]
# <a href="https://colab.research.google.com/github/samsonkaleti/HousePricePrediction/blob/main/HousePricePredition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv(r"/content/housing_price_dataset.csv")
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# SquareFeet      0
# Bedrooms        0
# Bathrooms       0
# Neighborhood    0
# YearBuilt       0
# Price           0
# dtype: int64

# %%
df["SquareFeet"].min() , df["SquareFeet"].max()
# Out:
# (1000, 2999)

# %%
df["Bedrooms"].min() , df["Bedrooms"].max()
# Out:
# (2, 5)

# %%
df["Bathrooms"].min() , df["Bathrooms"].max()
# Out:
# (1, 3)

# %%
df["YearBuilt"].min() , df["YearBuilt"].max()
# Out:
# (1950, 2021)

# %%
df["Price"].min() , df["Price"].max()
# Out:
# (-36588.16539749279, 492195.2599720151)

# %%
import numpy as np

# %%
df['Price'] = np.abs(df['Price'])

# %%
df["Price"].min() , df["Price"].max()
# Out:
# (154.77912007166017, 492195.2599720151)

# %%
df["Neighborhood"].unique()
# Out:
# array(['Rural', 'Suburb', 'Urban'], dtype=object)

# %%
df["Neighborhood"] = df["Neighborhood"].map({'Rural' : 0 , 'Suburb':1,'Urban' : 2})

# %%
df
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt          Price
# 0            2126         4          1             0       1969  215355.283618
# 1            2459         3          2             0       1980  195014.221626
# 2            1860         2          1             1       1970  306891.012076
# 3            2294         2          1             2       1996  206786.787153
# 4            2130         5          2             1       2001  272436.239065
# ...           ...       ...        ...           ...        ...            ...
# 49995        1282         5          3             0       1975  100080.865895
# 49996        2854         2          2             1       1988  374507.656727
# 49997        2979         5          3             1       1962  384110.555590
# 49998        2596         5          2             0       1984  380512.685957
# 49999        1572         5          3             0       2011  221618.583218
#
# ...

# %%
X = df.drop('Price',axis=1)
y = df['Price']

# %%
X
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt
# 0            2126         4          1             0       1969
# 1            2459         3          2             0       1980
# 2            1860         2          1             1       1970
# 3            2294         2          1             2       1996
# 4            2130         5          2             1       2001
# ...           ...       ...        ...           ...        ...
# 49995        1282         5          3             0       1975
# 49996        2854         2          2             1       1988
# 49997        2979         5          3             1       1962
# 49998        2596         5          2             0       1984
# 49999        1572         5          3             0       2011
#
# [50000 rows x 5 columns]

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2 , random_state=23)

# %%
X_test
# Out:
#        SquareFeet  Bedrooms  Bathrooms  Neighborhood  YearBuilt
# 49466        1055         3          2             0       1969
# 11621        1754         4          3             0       1973
# 39058        2872         4          3             2       1965
# 10033        1897         4          3             1       1985
# 22076        1212         3          3             1       1957
# ...           ...       ...        ...           ...        ...
# 16074        1546         5          2             2       1973
# 26432        2946         5          3             2       1990
# 17868        2718         4          2             1       1970
# 36795        2304         2          3             0       2005
# 39347        1951         5          3             1       1967
#
# [10000 rows x 5 columns]

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn = KNeighborsRegressor()
knn.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
ds = DecisionTreeRegressor()
ds.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
from sklearn.metrics import mean_squared_error

# %%
y_predit = knn.predict(X_test)
mean_squared_error(y_predit,y_test)
# Out:
# 2936820485.7985935

# %%
y_predit = lr.predict(X_test)
mean_squared_error(y_predit,y_test)
# Out:
# 2437868887.959436

# %%
y_predit = ds.predict(X_test)
mean_squared_error(y_predit,y_test)
# Out:
# 5202936062.204762

# %%
lr.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# model Deplyement

# %%
import pickle

# %%
with open('model.pkl','wb') as file :
  pickle.dump(lr,file)

# %%
import os
os.getcwd()
# Out:
# '/content'
